# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
#Definimos variables
n = 10000
a = 0
b = 1
data = np.random.uniform(a,b,n)

# %%
data
# Out:
# array([0.39480084, 0.33899936, 0.87706713, ..., 0.03231369, 0.95676734,
#        0.98092862])

# %%
type(data)
# Out:
# numpy.ndarray

# %%
len(data)
# Out:
# 10000

# %%
t = range(len(data))

# %%
t
# Out:
# range(0, 10000)

# %%
len(t)
# Out:
# 10000

# %%
# %matplotlib inline

# %%
plt.hist(data)
# Out:
# (array([ 953.,  956., 1010.,  990., 1018., 1017.,  999., 1040.,  994.,
#         1023.]),
#  array([2.07476586e-04, 1.00168042e-01, 2.00128608e-01, 3.00089173e-01,
#         4.00049739e-01, 5.00010304e-01, 5.99970870e-01, 6.99931435e-01,
#         7.99892001e-01, 8.99852567e-01, 9.99813132e-01]),
#  <a list of 10 Patch objects>)

# %%
data = np.random.randn(n)
x = range(1,n+1)

# %%
plt.plot(x,data)

# %%
plt.hist(data)
# Out:
# (array([   8.,   61.,  470., 1560., 2810., 2907., 1615.,  471.,   85.,
#           13.]),
#  array([-3.95892527, -3.17288867, -2.38685208, -1.60081549, -0.81477889,
#         -0.0287423 ,  0.7572943 ,  1.54333089,  2.32936749,  3.11540408,
#          3.90144068]),
#  <a list of 10 Patch objects>)

# %%
plt.plot(x,sorted(data))

# %%
errores= np.random.randn(n)

# %%
sigma = 16

# %%
errores*=sigma

# %%
plt.hist(errores)
# Out:
# (array([  10.,  102.,  586., 1661., 2921., 2751., 1440.,  450.,   73.,
#            6.]), array([-62.02003551, -49.47770236, -36.93536921, -24.39303606,
#         -11.85070291,   0.69163024,  13.23396339,  25.77629653,
#          38.31862968,  50.86096283,  63.40329598]), <a list of 10 Patch objects>)

# %%
np.var(errores)
# Out:
# 258.895350681012

# %%
len(x)
# Out:
# 10000

# %%
x = range(1,n+1)
a=0
b=2

# %%
#iMPORTAR DATOS

# %%
url_datos = "http://winterolympicsmedals.com/medals.csv"

# %%
models_data = pd.read_csv(url_datos)

# %%
models_data.head()
# Out:
#    Year      City       Sport      Discipline  NOC       Event Event gender  \
# 0  1924  Chamonix     Skating  Figure skating  AUT  individual            M
# 1  1924  Chamonix     Skating  Figure skating  AUT  individual            W
# 2  1924  Chamonix     Skating  Figure skating  AUT       pairs            X
# 3  1924  Chamonix   Bobsleigh       Bobsleigh  BEL    four-man            M
# 4  1924  Chamonix  Ice Hockey      Ice Hockey  CAN  ice hockey            M
#
#     Medal
# 0  Silver
# 1    Gold
# 2    Gold
# 3  Bronze
# 4    Gold

# %%
type(models_data)
# Out:
# pandas.core.frame.DataFrame

# %%
models_data.shape
# Out:
# (2311, 8)

# %%
models_data.columns.values
# Out:
# array(['Year', 'City', 'Sport', 'Discipline', 'NOC', 'Event',
#        'Event gender', 'Medal'], dtype=object)
